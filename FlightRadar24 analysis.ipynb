# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import requests
import folium
import datetime
import plotly.express as px
import plotly.graph_objects as go
from tqdm.notebook import tqdm
import time
import json
import re

# %% [markdown]
# # Изменения год к году

# %% [markdown]
# # Падение перелетов из России:

# %% [markdown]
# Основная гипотеза, которую я хочу проверить: Россия в результате событий 2022 и 2023 годов оказалась отрезана от мировых маршрутов авиаперевозок.

# %% [markdown]
# Для начала воспользуемся API Opensky network - сайта, предоставляющего информацию об авиарейсах. Однако, проблема этого источника в том, что он трекает совсем не все страны. Например, он не умеет трекать перелеты в Китае, почти всей Африке, Азии и Южной Америке. То есть там есть довольно точные данные о перелетах в Европе и Северной Америке, а об остальных регионах информации совсем мало. Однако, преимуществом данной апи является то, что данные тут можно получить очем быстро. Поэтому, чтобы дать причину делать гипотезу, которую я сделал, давайте посмотрим на количество перелетов из Шереметьево, главного аэропорта России, в разные места за неделю 4 июня-11 июня за 2023, 2022 и 2021 года. (Opensky разрешает получать данные о конкретном аэропорте не более чем за неделю)

# %%
username = 'Stankevich'
password = 'vonmi9-ruHcig-pabdij'

# %%
response = requests.get('https://opensky-network.org/api')

# %%
start_2023 = datetime.datetime(2023, 6, 1, 0, 0)
end_2023 = datetime.datetime(2023, 6, 8, 0, 0)

start_2023 = int(datetime.datetime.timestamp(start_2023))
end_2023 = int(datetime.datetime.timestamp(end_2023))

response = requests.get(f'https://opensky-network.org/api/flights/departure?airport=UUEE&begin={start_2023}&end={end_2023}')
print('Столько перелетов из Шереметьево за прошедшую неделю 2023 года', len(response.json()))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/requests/models.py in json(self, **kwargs)
#     909         try:
# --> 910             return complexjson.loads(self.text, **kwargs)
#     911         except JSONDecodeError as e:
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# /usr/lib/python3.10/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# /usr/lib/python3.10/json/decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-102-b1bfd3d60939> in <cell line: 8>()
#       6
#       7 response = requests.get(f'https://opensky-network.org/api/flights/departure?airport=UUEE&begin={start_2023}&end={end_2023}')
# ----> 8 print('Столько перелетов из Шереметьево за прошедшую неделю 2023 года', len(response.json()))
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in json(self, **kwargs)
#     915                 raise RequestsJSONDecodeError(e.message)
#     916             else:
# --> 917                 raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     918
#     919     @property
#
# JSONDecodeError: [Errno Expecting value] Sorry, something went wrong on our side. We have logged the error and will take action ASAP! If the problem persists for longer than a week, we would be happy if you contacted us: 0

# %%
start_2022 = datetime.datetime(2022, 6, 1, 0, 0)
end_2022 = datetime.datetime(2022, 6, 8, 0, 0)

start_2022 = int(datetime.datetime.timestamp(start_2022))
end_2022 = int(datetime.datetime.timestamp(end_2022))

response = requests.get(f'https://opensky-network.org/api/flights/departure?airport=UUEE&begin={start_2022}&end={end_2022}')
print('Столько перелетов из Шереметьево за прошедшую неделю 2022 года', len(response.json()))

# %%
start_2021 = datetime.datetime(2021, 6, 1, 0, 0)
end_2021 = datetime.datetime(2021, 6, 8, 0, 0)

start_2021 = int(datetime.datetime.timestamp(start_2021))
end_2021 = int(datetime.datetime.timestamp(end_2021))

response = requests.get(f'https://opensky-network.org/api/flights/departure?airport=UUEE&begin={start_2021}&end={end_2021}')
print('Столько перелетов из Шереметьево за прошедшую неделю 2021 года', len(response.json()))

# %% [markdown]
# Как видим, количество перелетов снизилось в разы за послдение 2 года. Но это лишь перелеты в ограниченное число стран, тут, например, нет Китая. Так что для более тщательного анализа попробуем поискать данные обо всем мире.

# %% [markdown]
# # Анализ данных FlightRadar24

# %% [markdown]
# Для оценки связи России с остальным миром авиапутями, сначала получим информацию обо всех перелетах в мире за неделю. Нам будет важно лишь количество самолетов, выполняющих рейсы по заданным маршрутам. Потом будем смотреть, получится ли выделить Россию в отдельный кластер и на сколько сильно Россия связана с другими странами.

# %% [markdown]
# Будем качать данные с флайт радара. Система там муторная в том плане, что после каждого запроса в аэропорт мы можем лишь узнать, в какие другие аэропорты оттуда есть перелеты. Далее же нам нужно делать запрос в конкретный маршрут из этого аэропорта в его "соседа", и только тогда можно будет получить данные о том, сколько самолетов летает по данному маршруту.

# %% [markdown]
# *1) Получим все аэропорты, которые доступны на FlighRadar24:*

# %%
s = requests.session()

# %%
#Все возможные аэропорты:
headers = {'User-Agent': 'Mac'}
r = s.get('https://www.flightradar24.com/data/airports/---', headers=headers)
all_airports = re.findall(r'\<small\>\(([A-Z]{3})/', r.text)

# %% [markdown]
# ### Функции для скачивания данных:

# %% [markdown]
# Скачивание данных - это был самый сложный процесс в проекте, на который ушло более 30 часов. FlightRadar очень сильно ограничивает количество запросов, поэтому пришлось разделить весь список аэропортов на буквы (всего 26) и отдельно сохранять по частям накопленную информацию.

# %% [markdown]
# *1.5) Разделим на группы:*

# %%
alphabet = 'qwertyuiopasdfghjklzxcvbnm'.upper()

airport_groups = {}

for sym in alphabet:
    airport_groups[sym] = []
    for i in all_airports:
        if i[0] == sym.upper():
            airport_groups[sym].append(i)
        
#Разбиваем на группки

# %%
#Пример для A
airport_groups['A'][:10]
# Out:
# ['AAH', 'AAL', 'AAR', 'ABD', 'ABA', 'ABZ', 'ABR', 'AHB', 'ABJ', 'ABI']

# %% [markdown]
# *2) Функция для нахождения доступных направлений из данного аэропорта:*

# %%
def get_airports_destinations(iata):
    """
    iata: str - IATA of the airport
    return: np.array - neighbour_iatas
    """
    time.sleep(1)
    headers = {"User-Agent": "Mac"}
    r = s.get(f'https://www.flightradar24.com/data/airports/{iata}/routes', headers=headers)
    
    #Таймлимит
    if re.findall('Just a moment', r.text):
        raise Exception('These capitalists in FlightRadar24.')
    
    #Нет рейсов
    try:
        r = json.loads(r.text.split("arrRoutes=")[-1].split(", arrDates=")[0])
    except:
        return np.array([['NO', 'NO']])

    neighbour_iatas = []
    for airport in r:
        neighbour_iatas.append((airport['iata'], airport['country'].title()))

    return np.array(neighbour_iatas)

# %%
#Пример для Шереметьево
svo = get_airports_destinations('SVO')
svo[:10]
# Out:
# array([['KBL', 'Afghanistan'],
#        ['ALG', 'Algeria'],
#        ['EVN', 'Armenia'],
#        ['VIE', 'Austria'],
#        ['GYD', 'Azerbaijan'],
#        ['GNJ', 'Azerbaijan'],
#        ['MSQ', 'Belarus'],
#        ['BRU', 'Belgium'],
#        ['PEK', 'China'],
#        ['PKX', 'China']], dtype='<U20')

# %% [markdown]
# *3) Функция для нахождения количества перелетов за неделю по всем направлениям для данного аэропорта:*

# %%
def get_number_of_flights(iata, neighbour_iatas):
    """
    iata: str - IATA of the airport (departure)
    neighbour_iatas: np.array - neighbour_iatas (arrivals)
    return: np.array - number of flights per week to arrival airport from departure airport
    """
    if neighbour_iatas[0,0] == 'NO' and neighbour_iatas[0,1] == 'NO':
        return [0]

    cookie = r.cookies.get_dict()
    headers = {"User-Agent": "Mac",
                "Content-Type": "application/json",
                "x-fetch": "true"}



    number_of_flights = []
    for neig, country in neighbour_iatas:
        s = requests.session()
        time.sleep(0.63)
        
        #На пустой респонс/не существует респонса
        try:
            response = s.get(f'https://www.flightradar24.com/data/airports/{iata.lower()}/routes?get-airport-arr-dep={neig.lower()}',
                             cookies=cookie, headers=headers).json()
            if response == []:
                number_of_flights.append(0)
                continue
        except:
            number_of_flights.append(0)
            continue
        

            
        #На таймлимит
        try:
            if response['error']:
                raise Exception('These capitalists in FlightRadar24.')
        except:
            pass


        #Если есть только departues
        try:
            if response['arrivals']:
                routes = response['arrivals'][country]['airports'][neig]['flights'].keys()
                n = 0
                for route in routes:
                    n += len(response['arrivals'][country]['airports'][neig]['flights'][route]['utc'])

                number_of_flights.append(n)
        except:
            number_of_flights.append(0)
                    

    return np.array(number_of_flights)

# %%
#Пример для Шереметьево
svo_flights = get_number_of_flights('SVO', svo)

# %%
svo_flights
# Out:
# array([  8,   4,   8,   8,  32,   8,   1,  48,  17,  16,   8,  29,  32,
#         88,  91,   8,  32,  16,   3,  33,  10,  43,  56,  52,  24,  16,
#         48,   8,  41,  16,  24,  47,   8,   8,  48,  17,   3,   3,   5,
#         74,   6,  24, 166, 237,  32,  24,  20,  18,  49,  59,   6,   4,
#         24,  42,  37, 101,  16])

# %% [markdown]
# *3) Функция для сохрананения информации обо всех аэропортах по букве:*

# %%
def get_dataframe(letter, cooldown = True):
    
    for iata in airport_groups[letter]:
        print(iata)
        
        #Если все норм
        try:
            destinations = get_airports_destinations(iata)
            flights = get_number_of_flights(iata, destinations)
            lines = []
            
            for i in range(len(destinations)):
                lines.append((iata, destinations[i][0], flights[i]))
                
        #Если банит     
        except:
            time.sleep(70)
            
            destinations = get_airports_destinations(iata)
            flights = get_number_of_flights(iata, destinations)
            lines = []
            
            for i in range(len(destinations)):
                lines.append((iata, destinations[i][0], flights[i]))

        #Сохраняем результат
        globals()[f'df_{iata}'] = pd.DataFrame(lines, columns = ['Departure', 'Arrival', 'Number of flights'])

# %% [markdown]
# *4) Функция для сохранения csv файла по одной букве локально*

# %%
def save_csv(letter):
    
    df = pd.DataFrame(columns = ['Departure', 'Arrival', 'Number of flights'])

    
    for iata in airport_groups[letter]:
        df = pd.concat([df, globals()[f'df_{iata}']])

        
    df.reset_index(drop = True, inplace=True)
    df.to_csv(f'{letter}_airports.csv', index=False)

# %% [markdown]
# После 30 часов пыток получили информацию о перелетах по всему миру за неделю.

# %% [markdown]
# ### Научимся получать информацию из IATA, ICAO аэропортов.

# %% [markdown]
# IATA -  это код аэропрта из 3 букв. ICAO - из 4 букв. На FlightRadar используется IATA. В пакетах, которые мы будем использовать для перевода кода аэропорта в информацию о нем - испольуется ICAO.

# %%
! pip install airportsdata
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting airportsdata
#   Downloading airportsdata-20230528-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 15.3 MB/s eta 0:00:00
# Installing collected packages: airportsdata
# Successfully installed airportsdata-20230528

# %% [markdown]
# Следующий пакет - для перевода кодов стран из 2-буквенных в названия стран.

# %%
! pip install country_converter --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting country_converter
#   Downloading country_converter-1.0.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.10/dist-packages (from country_converter) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->country_converter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->country_converter) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->country_converter) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0->country_converter) (1.16.0)
# Installing collected packages: country_converter
# Successfully installed country_converter-1.0.0

# %% [markdown]
# Это скачали на гитхабе как пакет с ICAO аэроптортов. Но, к сожалению, тут есть далеко не всё, поэтому скачаем еще одну табличку с аэропортами. Также везде поменяем названия стран с аббривеатур в 2 буквы в нормальное состояние.

# %%
import country_converter
import airportsdata
airportscoords = airportsdata.load()

# %%
#Создаем словарь для перевода IATA аэропорта в всю интересующую нас информацию
iata_info = {}
for icao in airportscoords.keys():
    iata_info[airportscoords[icao]['iata']] = {'name': airportscoords[icao]['name'],
                                               'city': airportscoords[icao]['city'],
                                               'country': airportscoords[icao]['country'],
                                               'lat': airportscoords[icao]['lat'],
                                               'lon': airportscoords[icao]['lon'],
                                               'tz': airportscoords[icao]['tz']}

#Используем еще один датасет, т.к. данный не знает много аэропортов
iatas = pd.read_csv('iatas.csv')
iatas = iatas.to_dict()

for row in iatas['code'].keys():
    if not (iatas['code'][row] in iata_info.keys()):
        iata_info[iatas['code'][row]] = {'name': iatas['name'][row],
                                         'city': iatas['city_code'][row],
                                         'country': iatas['country_id'][row],
                                         'lon': iatas['location'][row].split()[1][1:],
                                         'lat': iatas['location'][row].split()[2][:-1],
                                         'tz': iatas['time_zone_id'][row]}

#Почему-то в пакете Намибия превратилась в nan, видимо, человеческая ошибка. Меняем это.
for i in iata_info.keys():
  if iata_info[i]['country'] is np.nan:
    iata_info[i]['country'] = 'Namibia'                                         



#Останутся без городов около 60 аэропортов в итоге, среди них почти все имеют 1-2 перелета в неделю.

# %%
#все страны для перевода из двоичного названия в нормальное
countrydict ={}

abbrv_countries = []
for i in iata_info.keys():
    abbrv_countries.append(iata_info[i]['country'])

for abbrv in set(abbrv_countries):
    countrydict[abbrv] = country_converter.convert(abbrv, to = 'name_short')



for iata in iata_info.keys():
    iata_info[iata]['country'] = countrydict[iata_info[iata]['country']]

# %% [markdown]
# Вот пример того, что у нас получилось:

# %%
iata_info['SVO']
# Out:
# {'name': 'Sheremetyevo International Airport',
#  'city': 'Moscow',
#  'country': 'Russia',
#  'lat': 55.9725990295,
#  'lon': 37.4146003723,
#  'tz': 'Europe/Moscow'}

# %% [markdown]
# ### Работа с данными

# %% [markdown]
# Импортируем скачанные csv таблички и строим датафреймы из них:

# %%
import os
import glob

# %%
# !unzip /content/Airportcsvs.zip

# %%
data = pd.DataFrame()

for file in glob.glob('/content/Airportcsvs/*.csv'):
    data = pd.concat([data, pd.read_csv(file)])

data.reset_index(drop=True, inplace=True)

# %% [markdown]
# Удалим те маршруты, где нет перелетов на самом деле в течение недели и посмотрим на то, что у нас получилось.

# %%
data = data[data['Number of flights'] != 0]
print(data.shape)
data.sample(5)
# Out:
# (59323, 3)
#       Departure Arrival  Number of flights
# 30461       OMA     SFB                  2
# 13813       SMI     SKG                  8
# 44289       DPA     YHM                  1
# 52405       NTG     KWL                  4
# 22263       BBK     GBE                  3

# %% [markdown]
# ---

# %% [markdown]
# Добавим полученные данные в датасет с маршрутами:

# %%
data = data[data['Departure'].isin(iata_info.keys()) & data['Arrival'].isin(iata_info.keys())]

data['Departure_city'] = data['Departure'].apply(lambda x: iata_info[x]['city'])
data['Arrival_city'] = data['Arrival'].apply(lambda x: iata_info[x]['city'])

data['Departure_country'] = data['Departure'].apply(lambda x: iata_info[x]['country'])
data['Arrival_country'] = data['Arrival'].apply(lambda x: iata_info[x]['country'])

data['Departure_airport'] = data['Departure'].apply(lambda x: iata_info[x]['name'])
data['Arrival_airport'] = data['Arrival'].apply(lambda x: iata_info[x]['name'])

data['Departure_lat'] = data['Departure'].apply(lambda x: iata_info[x]['lat'])
data['Arrival_lat'] = data['Arrival'].apply(lambda x: iata_info[x]['lat'])

data['Departure_lon'] = data['Departure'].apply(lambda x: iata_info[x]['lon'])
data['Arrival_lon'] = data['Arrival'].apply(lambda x: iata_info[x]['lon'])

data['Departure_tz'] = data['Departure'].apply(lambda x: iata_info[x]['tz'])
data['Arrival_tz'] = data['Arrival'].apply(lambda x: iata_info[x]['tz'])

data.sample(5)
# Out:
# <ipython-input-45-ae5b14ed9de4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Departure_city'] = data['Departure'].apply(lambda x: iata_info[x]['city'])
#       Departure Arrival  Number of flights Departure_city    Arrival_city  \
# 4611        AGP     CWL                  6         Malaga         Cardiff
# 17099       SUV     LKB                  1        Nausori   Lakeba Island
# 52976       NCE     MLA                  2           Nice            Luqa
# 13738       SSA     SDU                 44       Salvador  Rio De Janeiro
# 29865       ORF     CMH                  2        Norfolk        Columbus
#
#       Departure_country Arrival_country  \
# 4611              Spain  United Kingdom
# 17099              Fiji            Fiji
# 52976            France           Malta
# 13738            Brazil          Brazil
# 29865     United States   United States
#
#                                        Departure_airport  \
# 4611                                      Malaga Airport
# 17099                      Nausori International Airport
# 52976                           Nice-Cote d'Azur Airport
# 13738  Deputado Luiz Eduardo Magalhaes International ...
# 29865                      Norfolk International Airport
#
#                                  Arrival_airport Departure_lat Arrival_lat  \
# 4611               Cardiff International Airport       36.6749   51.396702
# 17099                      Lakeba Island Airport    -18.043301    -18.1992
# 52976                               Luqa Airport     43.658401   35.857498
# 13738                      Santos Dumont Airport    -12.908611    -22.9105
# 29865  John Glenn Columbus International Airport     36.894604   39.996947
#
#       Departure_lon Arrival_lon      Departure_tz         Arrival_tz
# 4611       -4.49911    -3.34333     Europe/Madrid      Europe/London
# 17099    178.559006 -178.817001      Pacific/Fiji       Pacific/Fiji
# 52976       7.21587     14.4775      Europe/Paris       Europe/Malta
# 13738    -38.322498  -43.163101     America/Bahia  America/Sao_Paulo
# 29865    -76.201229  -82.892159  America/New_York   America/New_York

# %% [markdown]
# ---

# %% [markdown]
# Можем визуализировать один из аэропортов. Посмотрим, куда летают самолеты из аэропорта Стамбула IST

# %%
ist = data[data['Departure'] == 'IST']

# %%
#Точки, куда прилетает
fig = px.scatter_geo(ist,
                     lat = 'Arrival_lat',
                     lon = 'Arrival_lon',
                     hover_name='Arrival_city',
                     projection='orthographic',
                     size = 'Number of flights')



#Маршруты
for i in range(len(ist)):
    fig.add_trace(
        go.Scattergeo(
            hoverinfo = 'text',
            text = ist['Arrival_city'].iloc[i],
            lon = [ist['Arrival_lon'].iloc[i], ist['Departure_lon'].iloc[i]],
            lat = [ist['Arrival_lat'].iloc[i], ist['Departure_lat'].iloc[i]],
            mode = 'lines',
            line = dict(width = 0.1, color = 'blue')
        )
    )



#Стамбул
fig.add_scattergeo(lat = ist['Departure_lat'],
                   lon = ist['Departure_lon'],
                   hovertext = ist['Departure_city'])



fig.update_layout(margin=dict(l=3, r=3, t=0, b=0),
                  showlegend = False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c661c967-dded-4dcf-924f-f4dd29970a0b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c661c967-dded-4dcf-924f-f4dd29970a0b")) {                    Plotly.newPlot(                        "c661c967-dded-4dcf-924f-f4dd29970a0b",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Number of flights=%{marker.size}<br>Arrival_lat=%{lat}<br>Arrival_lon=%{lon}<extra></extra>","hovertext":["Kabul","Tirana","Algiers","Annabah","Constantine","Oran","Luanda","Yerevan","Salzburg","Vienna","Baku","Nakhchivan","Manama","Dhaka","Minsk","Brussels","Cotonou","Sarajevo","Sao Paulo","Sofia","Varna","Ouagadougou","Douala","Yaounde","Montreal","Toronto","Vancouver","N'Djamena","Beijing","Beijing","Guangzhou","Shanghai","Bogota","Dubrovnik","Zagreb","Havana","Prague","Kinshasa","Billund","Copenhagen","Djibouti City","Alexandria","Cairo","Hurghada","Sharm el-Sheikh","Asmara","Tallinn","Addis Ababa","Helsinki","Bale/Mulhouse","Bordeaux/Merignac","Lyon","Marseille","Nantes","Nice","Paris","Paris","Paris","Strasbourg","Toulouse/Blagnac","Libreville","Banjul","Batumi","Tbilisi","Berlin","Bremen","Cologne","Dusseldorf","Frankfurt am Main","Hamburg","Hannover","Leipzig","Lubeck","Munich","Nuremberg","Stuttgart","Accra","Athens","Rodes Island","Thessaloniki","Hong Kong","Budapest","Bangalore","Chennai","New Delhi","Mumbai","Denpasar-Bali Island","Jakarta","Isfahan","Mashhad","Shiraz","Tabriz","Tehran","Urmia","Najaf","Baghdad","Basrah","Arbil","Kirkuk","Dublin","Shannon","Tel Aviv","Bari","Bologna","Catania","Milan","Napoli","Palermo","Rome","Venezia","Tokyo","Tokyo","Amman","Aqaba","Aktau","Aktyubinsk","Almaty","Astana","Atyrau","Shymkent","Turkistan","Nairobi","Prishtina","Kuwait City","Bishkek","Riga","Beirut","Benghazi","MRA","Tripoli","Vilnius","Luxembourg","Kuala Lumpur","Male","Senou","Luqa","Nouakchott","Port Louis","Mexico City","Chisinau","Ulaanbaatar","Podgorica","Tivat","Casablanca","Fes","Marrakech","Tangier","Kathmandu","Amsterdam","Maastricht","Niamey","Abuja","Lagos","Skopje","Oslo","Muscat","Islamabad","Karachi","Lahore","Tocumen","Manila","Krak\u00f3w","Warsaw","Lisbon","Porto","Doha","Bucharest","Cluj-Napoca","Constanta","Iasi","Beslan","Chelyabinsk","Grozny","Kazan","Makhachkala","Mineralnyye Vody","Moscow","Moscow","Moscow","Trento","Nizhny Novgorod","Novosibirsk","Orenburg","Perm","Samara","Sochi","St. Petersburg","Stavropol","Tyumen","Ufa","Yekaterinburg","Kigali","Ad Dammam","Jeddah","Medina","Riyadh","Diass","Belgrad","KVO","Nis","Singapore","Ljubljana","Mogadishu","Cape Town","Johannesburg","Seoul","Juba","Barcelona","Bilbao","Madrid","Malaga","Valencia","Zaragoza","Khartoum","Gothenburg","Stockholm","Geneva","Zurich","Taipei","Dushanbe","Dar es Salaam","Arusha","Kiembi Samaki","Bangkok","Sfax","Tunis","Adana","Adiyaman","Agri","Ankara","Hatay","Antalya","Batman","BGG","Bodrum","Dalaman","Denizli","Diyarbakir","Edremit","Elazig","Nicosia","Erzincan","Erzurum","Gaziantep","Gazipasa","Igdir","Isparta","Istanbul","Izmir","Kahramanmaras","Kars","Kastamonu","Kayseri","Konya","Altintas","Malatya","Mardin","Amasya","Mus","Nevsehir","Ordu","RZV","Samsun","Sanliurfa","Siirt","Sinop","NKT","Sivas","Tokat","Trabzon","Van","Y\u00fcksekova","Zonguldak","Ashgabat","Abu Dhabi","Dubai","Jebel Ali","Sharjah","Birmingham","Edinburgh","Farnborough","Liverpool","London","London","London","Manchester","Nottingham","Atlanta","Boston","Chicago","CMH","Dallas-Fort Worth","Houston","Los Angeles","Miami","New York","Newark","San Francisco","Seattle","Washington","Bukhara","Fergana","Navoi","Samarkand","Tashkent","Urgench","Caracas","Hanoi","Ho Chi Minh City"],"lat":[34.5658988953,41.4146995544,36.6910018921,36.8222007751,36.2760009766,3 ...

# %% [markdown]
# ### Проанализируем как вообще обстоят дела в полетах, поищем интересные факты.

# %% [markdown]
# Сначала посмотрим, какие аэропорты вообще имеют больше всего перелетов.

# %%
total_flights_by_airports = (data.groupby('Arrival')['Number of flights'].sum() + 
                           data.groupby('Departure')['Number of flights'].sum())

total_flights_by_airports.fillna(data.groupby('Arrival')['Number of flights'].sum(), inplace = True)
total_flights_by_airports.fillna(data.groupby('Departure')['Number of flights'].sum(), inplace = True)

# %%
fig = px.bar(total_flights_by_airports.sort_values()[-15:],
             orientation='v',
             height = 500,
             title = 'Самые загруженные города мира')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7e63b279-3830-420a-a760-c744db2c3d52" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e63b279-3830-420a-a760-c744db2c3d52")) {                    Plotly.newPlot(                        "7e63b279-3830-420a-a760-c744db2c3d52",                        [{"alignmentgroup":"True","hovertemplate":"variable=Number of flights<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Number of flights","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Number of flights","offsetgroup":"Number of flights","orientation":"v","showlegend":true,"textposition":"auto","x":["CAN","CDG","HND","JFK","FRA","LHR","AMS","PVG","CLT","IST","LAX","DEN","DFW","ORD","ATL"],"xaxis":"x","y":[10055.0,10120.0,10186.0,10210.0,10221.0,10303.0,10553.0,10779.0,11070.0,11468.0,12312.0,14481.0,15575.0,16220.0,17116.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line": ...

# %% [markdown]
# Еще посмотрим на то, какие города больше всего загружены:

# %%
total_flights = pd.DataFrame(columns = ['iata','airport', 'lat', 'lon', 'number of flights', 'city', 'country'])

total_flights['iata'] = total_flights_by_airports.index
total_flights['number of flights'] = total_flights_by_airports.values
total_flights['airport'] = total_flights['iata'].apply(lambda x: iata_info[x]['name'])
total_flights['lat'] = total_flights['iata'].apply(lambda x: iata_info[x]['lat'])
total_flights['lon'] = total_flights['iata'].apply(lambda x: iata_info[x]['lon'])
total_flights['city'] = total_flights['iata'].apply(lambda x: iata_info[x]['city'])
total_flights['country'] = total_flights['iata'].apply(lambda x: iata_info[x]['country'])
total_flights['city'].loc[total_flights['city'] == ''] = total_flights[total_flights['city'] == '']['airport']
# Out:
# <ipython-input-51-af0649d4b922>:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
total_flights_by_city = total_flights.drop_duplicates(subset = ['city',	'country'])[['city','country','lat','lon']].merge(
                                                      total_flights.groupby(['country', 'city'], as_index=False)['number of flights'].sum())

# %% [markdown]
# Сгруппировали все по городам, теперь посмотрим на то, какие города самые нагруженные по общему количеству перелетов.

# %%
fig = px.scatter_geo(total_flights_by_city,
                     hover_name='city',
                     lat='lat',
                     lon = 'lon',
                     color = 'country',
                     size = 'number of flights'
                     )

fig.update_layout(margin=dict(l=3, r=3, t=0, b=0),
                  showlegend = False,
                  geo = dict(scope = 'usa'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d20f6a3d-7854-475c-8dcd-b734d56c471a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d20f6a3d-7854-475c-8dcd-b734d56c471a")) {                    Plotly.newPlot(                        "d20f6a3d-7854-475c-8dcd-b734d56c471a",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=French Polynesia<br>number of flights=%{marker.size}<br>lat=%{lat}<br>lon=%{lon}<extra></extra>","hovertext":["Anaa Airport","Ahe Atoll","Apataki","Hiva Oa-Atuona Airport","Arutua Airport","Motu Mute","Fakarava Airport","Totegegie Airport","Hikueru Atoll","Hao Airport","Fare","Kauehi","Kaukura Airport","KXU","Maupiti Airport","Makemo Airport","Moorea Airport","Mataiva Airport","Nuku Hiva Airport","Papeete","Pukarua","Uturoa","Rangiroa Airport","Aratika Nord Airport","RMT","Rurutu Airport","Raivavae Airport","Tikehau Airport","Takapoto Airport","Tatakoto","Takaroa Airport","Tubuai Airport","Ua Huka","Ua Pou","Manihi Airport","Tureia Airport"],"lat":[-17.3526000977,-14.4280996323,-15.5735998154,-9.7687902451,-15.2482995987,-16.4444007874,-16.0541000366,-23.0799007416,-17.5447006226,-18.0748004913,-16.6872005463,-15.7807998657,-15.6632995605,"-16.3393993",-16.4265003204,-16.5839004517,-17.4899997711,-14.8681001663,-8.7955999374,-17.5536994934,-18.2956008911,-16.7229003906,-14.9542999268,-15.4853000641,"-22.6382712",-22.4340991974,-23.8852005005,-15.119600296,-14.7095003128,-17.3553009033,-14.4558000565,-23.3654003143,-8.9361095428,-9.3516702652,-14.4368000031,-20.7896995544],"legendgroup":"French Polynesia","lon":[-145.5099945068,-146.2570037842,-146.4149932861,-139.0110015869,-146.6170043945,-151.7510070801,-145.6569976807,-134.8899993896,-142.6139984131,-140.9459991455,-151.0220031738,-145.1239929199,-146.8849945068,"-144.4029999",-152.2440032959,-143.6580047607,-149.7619934082,-148.7169952393,-140.2290039063,-149.606994629,-137.016998291,-151.466003418,-147.6609954834,-145.470001221,"-152.8053277",-151.3609924316,-147.662002563,-148.2310028076,-145.2460021973,-138.4450073242,-145.0249938965,-149.5240020752,-139.5520019531,-140.0780029297,-146.0700073242,-138.5700073242],"marker":{"color":"#636efa","size":[1.0,6.0,2.0,33.0,6.0,220.0,17.0,4.0,1.0,9.0,76.0,2.0,2.0,2.0,24.0,4.0,43.0,6.0,43.0,534.0,2.0,169.0,82.0,2.0,4.0,12.0,3.0,24.0,1.0,4.0,5.0,11.0,6.0,6.0,6.0,1.0],"sizemode":"area","sizeref":62.2625,"symbol":"circle"},"mode":"markers","name":"French Polynesia","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Somalia<br>number of flights=%{marker.size}<br>lat=%{lat}<br>lon=%{lon}<extra></extra>","hovertext":["AAD","Baidoa","Bosaso","GGR","Galcaio","Hargeisa","Kisimayu Airport","Mogadishu"],"lat":["6.09628635",3.1022200584,11.2753000259,"8.283333",6.7808299065,9.5181703568,-0.3773530126,2.0144400597],"legendgroup":"Somalia","lon":["46.637708371259194",43.6286010742,49.1493988037,"48.333332",47.45470047,44.0887985229,42.4592018127,45.3046989441],"marker":{"color":"#EF553B","size":[1.0,2.0,31.0,56.0,23.0,117.0,14.0,235.0],"sizemode":"area","sizeref":62.2625,"symbol":"circle"},"mode":"markers","name":"Somalia","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Algeria<br>number of flights=%{marker.size}<br>lat=%{lat}<br>lon=%{lon}<extra></extra>","hovertext":["Annabah","Algiers","Touat Cheikh Sidi Mohamed Belkebir Airport","Bejaia","Batna","Bordj Badji Mokhtar","Biskra","Bechar","Chlef","Constantine","Djanet","El Bayadh","El Golea Airport","Guemar","Ghardaia","Jijel","Hassi Messaoud","Amenas","In Guezzam","Laghouat","Mecheria","Ouargla","Oran","Setif","Tebessi","Touggourt","Tiaret","Tindouf","Tlemcen","Tamanrasset","Timimoun" ...

# %%
total_flights_by_city
# Out:
#                 city           country         lat                 lon  \
# 0       Anaa Airport  French Polynesia    -17.3526         -145.509995
# 1                AAD           Somalia  6.09628635  46.637708371259194
# 2            Annabah           Algeria   36.822201             7.80917
# 3       Apalachicola     United States   29.727549          -85.027378
# 4            Buariki          Kiribati    0.185278          173.636993
# ...              ...               ...         ...                 ...
# 4347  Wollaston Lake            Canada   58.106899         -103.171997
# 4348           Zunyi             China     27.5895            107.0007
# 4349          Sylhet        Bangladesh     24.9632           91.866798
# 4350      Tymovskoye            Russia   50.669201          142.761002
# 4351      Zanesville     United States   39.944446          -81.892094
#
#       number of flights
# 0                   1.0
# 1                   1.0
# 2                 123.0
# 3                   1.0
# 4                   4.0
# ...                 ...
# 4347               14.0
# 4348              379.0
# 4349              222.0
# 4350                4.0
# 4351                7.0
#
# [4352 rows x 5 columns]

# %%
total_flights_by_city.sort_values('number of flights', inplace=True)

fig = px.bar(total_flights_by_city[-25:], x = 'number of flights', y = 'city',
             orientation='h',
             color = 'country',
             height = 700,
             title = 'Самые загруженные города мира')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="56ac02b2-9299-4c81-97f8-a648ca7bde1a" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56ac02b2-9299-4c81-97f8-a648ca7bde1a")) {                    Plotly.newPlot(                        "56ac02b2-9299-4c81-97f8-a648ca7bde1a",                        [{"alignmentgroup":"True","hovertemplate":"country=South Korea<br>number of flights=%{x}<br>city=%{y}<extra></extra>","legendgroup":"South Korea","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"South Korea","offsetgroup":"South Korea","orientation":"h","showlegend":true,"textposition":"auto","x":[9466.0],"xaxis":"x","y":["Seoul"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=United States<br>number of flights=%{x}<br>city=%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"h","showlegend":true,"textposition":"auto","x":[9537.0,11070.0,11764.0,12008.0,12312.0,14718.0,15575.0,17196.0,18565.0,20416.0],"xaxis":"x","y":["Seattle","Charlotte","Washington","Houston","Los Angeles","Denver","Dallas-Fort Worth","Atlanta","New York","Chicago"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=China<br>number of flights=%{x}<br>city=%{y}<extra></extra>","legendgroup":"China","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"h","showlegend":true,"textposition":"auto","x":[9666.0,10055.0,16041.0,16925.0],"xaxis":"x","y":["Shenzhen","Guangzhou","Beijing","Shanghai"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=India<br>number of flights=%{x}<br>city=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"h","showlegend":true,"textposition":"auto","x":[9817.0],"xaxis":"x","y":["New Delhi"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=Indonesia<br>number of flights=%{x}<br>city=%{y}<extra></extra>","legendgroup":"Indonesia","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Indonesia","offsetgroup":"Indonesia","orientation":"h","showlegend":true,"textposition":"auto","x":[10057.0],"xaxis":"x","y":["Jakarta"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=Germany<br>number of flights=%{x}<br>city=%{y}<extra></extra>","legendgroup":"Germany","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Germany","offsetgroup":"Germany","orientation":"h","showlegend":true,"textposition":"auto","x":[10221.0],"xaxis":"x","y":["Frankfurt am Main"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=Thailand<br>number of flights=%{x}<br>city=%{y}<extra></extra>","legendgroup":"Thailand","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Thailand","offsetgroup":"Thailand","orientation":"h","showlegend":true,"textposition":"auto","x":[10271.0],"xaxis":"x","y":["Bangkok"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=Russia<br>number of flights=%{x}<br>city=%{y}<extra></extra>","legendgroup":"Russia","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Russia","offsetgroup":"Russia","orientation":"h","showlegend":true,"textposition":"auto","x":[10490.0],"xaxis":"x","y":["Moscow"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=Netherlands<br>number of flights=%{x}<br>city=%{y}<extra></extra>","legendgroup":"Netherlands","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Netherlands","offsetgroup":"Netherlands","orientation":"h","showlegend":true,"textposition":"auto","x":[10553.0],"xaxis":"x ...

# %% [markdown]
# Также, интересно посмотреть на самые загруженные авиамаршруты мира

# %%
most_busy_routes = pd.DataFrame()
most_busy_routes['Route'] = data['Departure_city'] + '-' + data['Arrival_city']
most_busy_routes['Number of flights'] = (data + data.rename(columns = {'Departure_city':'Arrival_city', 'Arrival_city':'Departure_city'}))['Number of flights']
most_busy_routes.sort_values('Number of flights', inplace = True)

# %%
fig = px.bar(most_busy_routes[-30:], y = 'Number of flights', x = 'Route',
             orientation='v',
             height = 700,
             title = 'Самые загруженные маршруты мира')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a37d4af7-429a-4a1d-bddf-b64656d7a8db" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a37d4af7-429a-4a1d-bddf-b64656d7a8db")) {                    Plotly.newPlot(                        "a37d4af7-429a-4a1d-bddf-b64656d7a8db",                        [{"alignmentgroup":"True","hovertemplate":"Route=%{x}<br>Number of flights=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Rionegro-Bogota","Da Nang-Hanoi","Hanoi-Da Nang","Sydney-Brisbane","Brisbane-Sydney","Cape Town-Johannesburg","Rio De Janeiro-Sao Paulo","Johannesburg-Cape Town","Sao Paulo-Rio De Janeiro","Medan-Sumatra Island-Jakarta","Jakarta-Medan-Sumatra Island","Ujung Pandang-Celebes Island-Jakarta","Jakarta-Ujung Pandang-Celebes Island","Riyadh-Jeddah","New Delhi-Mumbai","Tokyo-Fukuoka","Mumbai-New Delhi","Jeddah-Riyadh","Fukuoka-Tokyo","Denpasar-Bali Island-Jakarta","Tokyo-Chitose / Tomakomai","Jakarta-Denpasar-Bali Island","Chitose / Tomakomai-Tokyo","Hanoi-Ho Chi Minh City","Ho Chi Minh City-Hanoi","Kiembi Samaki-Dar es Salaam","Melbourne-Sydney","Sydney-Melbourne","Jeju City-Seoul","Seoul-Jeju City"],"xaxis":"x","y":[674,700,706,728,734,754,766,766,770,780,780,818,824,838,886,888,890,894,896,994,996,998,1000,1016,1028,1076,1212,1220,1546,1566],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556 ...

# %% [markdown]
# ---

# %% [markdown]
# ### Кластеризация

# %% [markdown]
# Теперь давайте составим граф, вершинами которого будут являться города, а ребрами будут перелеты. Соответсвенно, веса ребер - количество перелетов между городами. Хотим попробовать "выцепить" Россию в отдельном кластере при проделывании процедуры спектральной кластеризации.

# %%
! pip install networkx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.1)

# %%
import networkx as nx

# %%
#множество вершин:
vertexes = set([*data['Departure'], *data['Arrival']])
len(vertexes)
# Out:
# 4489

# %% [markdown]
# Создаем Лапласиан графа:

# %%
G = nx.MultiGraph()

#all cities
G.add_nodes_from(vertexes)

#all flights
e = list(zip(data['Arrival'], data['Departure'], data['Number of flights']))

G.add_weighted_edges_from(e, weight = 'flights') 
L = nx.laplacian_matrix(G)

# %% [markdown]
# ---

# %%
from sklearn.base import ClusterMixin
from sklearn.cluster import KMeans


class GraphClustering(ClusterMixin):
    def __init__(self, n_clusters=8, n_components=None, **kwargs):
        if n_components is None:
            n_components = n_clusters

        self.n_components = n_components
        self.kmeans = KMeans(n_clusters=n_clusters, **kwargs)

    def fit_predict(self, L, y=None):
        eigenvectors = self._generate_eigenvectors(L)
        labels = self.kmeans.fit_predict(eigenvectors[:, 1:])
        return labels

    def _generate_eigenvectors(self, L):
        if self.n_components is None:
          return np.linalg.eigh(L)[1]
        else:
          return np.linalg.eigh(L)[1][:,:self.n_components]

# %% [markdown]
# Зафитим модель, потом добавим лейблы в датафрейм и визуализируем. Если выбирать слишком маленькое число кластеров, то будут отваливаться маленькие зоны, мы же хотим чтобы появились большие кластеры, поэтому выберем n_clusters 180.

# %%
model = GraphClustering(n_clusters=180)
labels = model.fit_predict(L.todense())
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %%
airports = pd.DataFrame()

airports['label'] = labels
airports['airport'] = list(vertexes)
airports['lat'] = airports['airport'].apply(lambda x: iata_info[x]['lat'])
airports['lon'] = airports['airport'].apply(lambda x: iata_info[x]['lon'])
airports['number of flights'] = airports['airport'].apply(lambda x: G.degree(weight = 'flights')[x])
airports['country'] = airports['airport'].apply(lambda x: iata_info[x]['country'])

# %%
airports.sample(5)
# Out:
#       label airport          lat                lon  number of flights  \
# 3621      0     BWA    27.505699          83.416298                280
# 199       0     YTW  36.80990525  81.79149269333863                 69
# 2363    170     TPQ      21.4195        -104.843002                 48
# 1161    167     BWB   -20.864401         115.405998                  2
# 4079      0     VLI   -17.699301         168.320007                124
#
#         country
# 3621      Nepal
# 199       China
# 2363     Mexico
# 1161  Australia
# 4079    Vanuatu

# %%
fig = px.scatter_geo(airports,
                     hover_name='airport',
                     lat='lat',
                     lon = 'lon',
                     color = 'label'
                     )

fig.update_layout(margin=dict(l=3, r=3, t=0, b=0),
                  showlegend = False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="07356c6f-313b-441e-b30e-d41abdce009f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07356c6f-313b-441e-b30e-d41abdce009f")) {                    Plotly.newPlot(                        "07356c6f-313b-441e-b30e-d41abdce009f",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>lat=%{lat}<br>lon=%{lon}<br>label=%{marker.color}<extra></extra>","hovertext":["ELU","SHA","TCG","FWA","AFA","ENW","GEG","LYG","PEX","BZR","YNZ","SWA","AGP","EME","AES","BSA","YDV","NPY","BKI","DMK","IZA","CXI","SOB","GDQ","KUL","AUA","HVB","CHY","SDR","LYS","MFU","TIW","HZK","AUZ","SLA","CYF","PDV","CDV","MPM","IDA","BIQ","LJU","LOS","WTE","INU","HON","EDN","IXC","BOG","ZQW","JHM","AWD","AEP","THL","SMA","BRC","GYY","CNJ","KIK","CAZ","PIT","BSD","EPL","BER","LAW","BVX","POL","LUD","CKD","OSJ","CNP","CET","BVY","PEG","CUB","CYB","HKG","FPO","JBQ","VUP","AUO","CUZ","POM","AXA","CIK","PIR","JCK","SEU","DAT","DCY","ZBY","HFN","ALG","BDQ","WKA","RJN","FPR","VJB","VER","ROZ","MRE","NVI","CCS","JIO","KFE","RGA","GOV","VKT","FLG","BGF","LIH","CVG","CTZ","FTU","ROW","VCT","SLD","ELC","HMS","LAE","MOQ","TJS","TLC","IPC","KGD","DIU","SGD","JRO","TOD","EMA","LWB","HDG","JSJ","SXM","IPI","MCW","HSN","GYN","PWT","SPA","XIC","GEO","GBT","GMZ","ABT","YYF","SOJ","LBJ","CUF","MRW","PDK","DMD","SFM","AWM","SSG","PGA","SHS","GLR","GUS","MUR","AVL","ZAL","TMB","WDS","RON","MBT","HDM","CCK","BHV","PYM","MIQ","MLO","RMS","JXA","XIL","REP","LKN","PWA","PTQ","GYE","ODY","TKQ","CCP","KWJ","KMV","MUH","LOD","MGF","POW","RBD","OVD","CJS","MYD","GAM","NVA","VAS","PNE","TXK","QGP","YTW","BDA","ELQ","JHF","KKJ","VBP","RNB","NLH","NGS","BWX","PAC","MVD","OXF","HND","BVE","LBL","LKH","CIW","QOW","RAB","SDP","BGW","UKK","HYG","HSL","QCY","CAT","MSH","KWL","NTN","WRT","YSQ","MUA","CAI","SDK","EBA","AST","RIS","ROV","RUN","SXP","RMQ","HTG","BNE","WXN","ASL","PUZ","TZX","BMG","BPX","MPA","NSK","RDD","LSP","HNL","NDG","KRR","HCJ","YFJ","ULK","JPA","TAO","GPZ","IWD","RVV","MPY","BIU","SVQ","HNB","SFN","NDJ","GRB","NVT","DCA","MWX","KYU","BKQ","KHV","ENE","LNY","PMD","BWG","ISM","CLS","JIA","CEG","OLC","DLS","KCM","DYR","SHI","YQB","SKK","AGC","DIB","RMP","JAU","EVG","ALF","FKI","CJA","YAK","BYP","PMG","ALH","GBE","AHJ","MRA","PAP","HUM","PFQ","YRS","MMK","YVB","NSI","DCU","CHA","GIT","CYO","NUX","LHA","WTD","VAG","XIY","AAT","BOI","WVI","BLM","YHZ","BKO","HRE","TYN","NBX","CGR","ABM","TLM","RSU","YNY","TKJ","OZC","LGD","SVX","LRM","HYC","ZLO","YPX","VDI","OSY","MAM","RBY","GAS","DMM","ZVK","GDX","DWH","JJD","OPO","CKV","STD","BJA","ATT","NYA","VAR","GOM","AUU","AAZ","CKM","BSK","PPN","MIJ","TUL","SHH","BED","EWB","BVA","GSM","GVT","IMT","MZK","MNI","POA","ONK","TAD","WGE","KDV","MZA","ERL","STE","TMR","MMD","TFN","EAM","UIH","KKE","IGT","LYA","MDI","BIB","AKC","AYT","PBG","AXD","ADD","DDD","AHU","DNH","DBQ","MCP","OAL","LBA","CUQ","YGX","BCB","SLV","YMM","CHR","TBI","FCO","PIP","YSJ","WVB","RDO","LBF","YIK","MKQ","IPA","PDB","AGS","SJJ","RAO","IPT","LUL","GAJ","PTX","GTZ","AJL","APA","TRS","KIT","FUK","FDE","NIG","BKK","JLN","CLM","TAS","OGD","TAH","RNI","RRS","TEZ","MOV","HAU","XTG","DYU","TOF","AXJ","ASH","IKT","YTQ","CIX","DAD","PKX","TLI","WST","DPS","MFD","GOI","KUU","PKU","MLH","MML","KFP","PRI","UTP","APG","PTH","NOJ","KWA","ASE","MME","JEF","AKL","ZSE","HBG","TNR","TRM","RNH","LTK","TGP","TJL","KWM","WBM","JMU","CAY","SRY","KKI","QUO","LLF","CEL","SEA","NOT","BHU","ELD","WRZ","KCI","AYP","ZHY","HDF","SDL","MEH","MEU","NAM","NDU","HEZ","BCI","SHC","LMM","LYP","LYC","BEJ","BEL","HKD","GAO","KGE","ICT","GFL","MNG","STI","ISG","CRP","BRL","BQJ","SWF","MYR","LBY","YRA","KDI","VGZ","TMT","JBR","EVV","PEI","IRJ","XRY","FNA","JUJ","NMA","JEJ","CED","KZR","YKO","CHT","OER ...

# %% [markdown]
# Перезапускал алгоритм несколько раз. Иногда Северная и Южная Америки отделялись от кластера Евразия-Африка, когда-то же отделялась отдельно Южная Америка, Северная Америка и Евразия-Африка. Но абсолютно всегда оставались аномальные зоны, в которых явно выделялись отдельные кластера: это северные территории такие как Аляска, Север Норвегии, Гудзонов залив, Северо-Восточная Сибирь, а также отделялись Западная Австралия, Кения и Иран. Понятно, что также туда попадают всякие единичные отдаленные аэропорты или группы аэропортов, но я выделил самые постоянные и большие.

# %%
fig = px.scatter_geo(airports,
                     hover_name='airport',
                     lat='lat',
                     lon = 'lon',
                     color = 'label',
                     size = 'number of flights',
                     #projection='orthographic'
                     )

fig.update_layout(margin=dict(l=3, r=3, t=0, b=0),
                  showlegend = False, geo = dict(scope = 'south america'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="6072f9f0-60c9-4a84-b7c5-81662c5f60bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6072f9f0-60c9-4a84-b7c5-81662c5f60bd")) {                    Plotly.newPlot(                        "6072f9f0-60c9-4a84-b7c5-81662c5f60bd",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>number of flights=%{marker.size}<br>lat=%{lat}<br>lon=%{lon}<br>label=%{marker.color}<extra></extra>","hovertext":["ELU","SHA","TCG","FWA","AFA","ENW","GEG","LYG","PEX","BZR","YNZ","SWA","AGP","EME","AES","BSA","YDV","NPY","BKI","DMK","IZA","CXI","SOB","GDQ","KUL","AUA","HVB","CHY","SDR","LYS","MFU","TIW","HZK","AUZ","SLA","CYF","PDV","CDV","MPM","IDA","BIQ","LJU","LOS","WTE","INU","HON","EDN","IXC","BOG","ZQW","JHM","AWD","AEP","THL","SMA","BRC","GYY","CNJ","KIK","CAZ","PIT","BSD","EPL","BER","LAW","BVX","POL","LUD","CKD","OSJ","CNP","CET","BVY","PEG","CUB","CYB","HKG","FPO","JBQ","VUP","AUO","CUZ","POM","AXA","CIK","PIR","JCK","SEU","DAT","DCY","ZBY","HFN","ALG","BDQ","WKA","RJN","FPR","VJB","VER","ROZ","MRE","NVI","CCS","JIO","KFE","RGA","GOV","VKT","FLG","BGF","LIH","CVG","CTZ","FTU","ROW","VCT","SLD","ELC","HMS","LAE","MOQ","TJS","TLC","IPC","KGD","DIU","SGD","JRO","TOD","EMA","LWB","HDG","JSJ","SXM","IPI","MCW","HSN","GYN","PWT","SPA","XIC","GEO","GBT","GMZ","ABT","YYF","SOJ","LBJ","CUF","MRW","PDK","DMD","SFM","AWM","SSG","PGA","SHS","GLR","GUS","MUR","AVL","ZAL","TMB","WDS","RON","MBT","HDM","CCK","BHV","PYM","MIQ","MLO","RMS","JXA","XIL","REP","LKN","PWA","PTQ","GYE","ODY","TKQ","CCP","KWJ","KMV","MUH","LOD","MGF","POW","RBD","OVD","CJS","MYD","GAM","NVA","VAS","PNE","TXK","QGP","YTW","BDA","ELQ","JHF","KKJ","VBP","RNB","NLH","NGS","BWX","PAC","MVD","OXF","HND","BVE","LBL","LKH","CIW","QOW","RAB","SDP","BGW","UKK","HYG","HSL","QCY","CAT","MSH","KWL","NTN","WRT","YSQ","MUA","CAI","SDK","EBA","AST","RIS","ROV","RUN","SXP","RMQ","HTG","BNE","WXN","ASL","PUZ","TZX","BMG","BPX","MPA","NSK","RDD","LSP","HNL","NDG","KRR","HCJ","YFJ","ULK","JPA","TAO","GPZ","IWD","RVV","MPY","BIU","SVQ","HNB","SFN","NDJ","GRB","NVT","DCA","MWX","KYU","BKQ","KHV","ENE","LNY","PMD","BWG","ISM","CLS","JIA","CEG","OLC","DLS","KCM","DYR","SHI","YQB","SKK","AGC","DIB","RMP","JAU","EVG","ALF","FKI","CJA","YAK","BYP","PMG","ALH","GBE","AHJ","MRA","PAP","HUM","PFQ","YRS","MMK","YVB","NSI","DCU","CHA","GIT","CYO","NUX","LHA","WTD","VAG","XIY","AAT","BOI","WVI","BLM","YHZ","BKO","HRE","TYN","NBX","CGR","ABM","TLM","RSU","YNY","TKJ","OZC","LGD","SVX","LRM","HYC","ZLO","YPX","VDI","OSY","MAM","RBY","GAS","DMM","ZVK","GDX","DWH","JJD","OPO","CKV","STD","BJA","ATT","NYA","VAR","GOM","AUU","AAZ","CKM","BSK","PPN","MIJ","TUL","SHH","BED","EWB","BVA","GSM","GVT","IMT","MZK","MNI","POA","ONK","TAD","WGE","KDV","MZA","ERL","STE","TMR","MMD","TFN","EAM","UIH","KKE","IGT","LYA","MDI","BIB","AKC","AYT","PBG","AXD","ADD","DDD","AHU","DNH","DBQ","MCP","OAL","LBA","CUQ","YGX","BCB","SLV","YMM","CHR","TBI","FCO","PIP","YSJ","WVB","RDO","LBF","YIK","MKQ","IPA","PDB","AGS","SJJ","RAO","IPT","LUL","GAJ","PTX","GTZ","AJL","APA","TRS","KIT","FUK","FDE","NIG","BKK","JLN","CLM","TAS","OGD","TAH","RNI","RRS","TEZ","MOV","HAU","XTG","DYU","TOF","AXJ","ASH","IKT","YTQ","CIX","DAD","PKX","TLI","WST","DPS","MFD","GOI","KUU","PKU","MLH","MML","KFP","PRI","UTP","APG","PTH","NOJ","KWA","ASE","MME","JEF","AKL","ZSE","HBG","TNR","TRM","RNH","LTK","TGP","TJL","KWM","WBM","JMU","CAY","SRY","KKI","QUO","LLF","CEL","SEA","NOT","BHU","ELD","WRZ","KCI","AYP","ZHY","HDF","SDL","MEH","MEU","NAM","NDU","HEZ","BCI","SHC","LMM","LYP","LYC","BEJ","BEL","HKD","GAO","KGE","ICT","GFL","MNG","STI","ISG","CRP","BRL","BQJ","SWF","MYR","LBY","YRA","KDI","VGZ","TMT","JBR","EVV","PEI","IRJ","XRY","FNA","JUJ","NMA ...

# %% [markdown]
# То, почему Южная Америка выделилась в отдельный кластер можно объяснить тем, что в ней очень много перелетов внутренних, как мы это увидим дальше. В общем число перелетов здесь выше, чем в среднем в Азии, Океании или Африке. Тут сильны внутренние перелеты, в итоге образуется отдельный кластер.

# %% [markdown]
# ---

# %% [markdown]
# ### Исследуем связи между странами

# %% [markdown]
# Для того, чтобы понять, насколько созависимы страны, будем использовать normalized_cut_size графа. По сути, результат будет показывать, насколько сильны связи между двумя странами, учитывая общее число связей каждой из стран. Для примера посмотрим Беларусь, Россию, Иран (который у нас выделился в отдельный кластер в прошлом разделе) и Чехию.

# %%
codependence = pd.DataFrame(columns = ['country', 'codependence'])
graph_countries = airports['country']

for i in graph_countries.unique():
    S = np.array(G.nodes)[graph_countries == 'Belarus']
    T = np.array(G.nodes)[graph_countries == i]

    if nx.normalized_cut_size(G, S, T) !=0:
        codependence = pd.concat([codependence, pd.DataFrame(columns = ['country', 'codependence'],
                                                             data = [[i, nx.normalized_cut_size(G, S, T, weight = 'flights')]])])



codependence.sort_values(by = 'codependence', inplace = True)
fig = px.bar(codependence, y = 'codependence', x = 'country', orientation='v',
             color = 'codependence',
             height = 500,
             title = 'Созависимость с Беларусью')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e09c76fe-3e30-4474-8463-f4880fea7de2" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e09c76fe-3e30-4474-8463-f4880fea7de2")) {                    Plotly.newPlot(                        "e09c76fe-3e30-4474-8463-f4880fea7de2",                        [{"alignmentgroup":"True","hovertemplate":"country=%{x}<br>codependence=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0.008985773564247939,0.012963463636109375,0.016998848229371904,0.022255517123992923,0.029889784559121488,0.03199636067803005,0.03348484793998871,0.050909974215488575,0.061348538011066205,0.15888030807049042,0.6626764302402229],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["China","Turkmenistan","Qatar","Armenia","Uzbekistan","Kazakhstan","Azerbaijan","United Arab Emirates","T\u00fcrkiye","Georgia","Russia"],"xaxis":"x","y":[0.008985773564247939,0.012963463636109375,0.016998848229371904,0.022255517123992923,0.029889784559121488,0.03199636067803005,0.03348484793998871,0.050909974215488575,0.061348538011066205,0.15888030807049042,0.6626764302402229],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern" ...

# %% [markdown]
# Как-то грустно. Очень большая созависимость с Россией, в то время как с другими странами перелетов совсем немного. А еще тут нет самой Беларуси, то есть там нет внутренних перелетов. Оказывается, в Беларуси есть только один аэропорт в Минске и, соответственно, внутренних перелетов нет.

# %%
codependence = pd.DataFrame(columns = ['country', 'codependence'])
graph_countries = airports['country']

for i in graph_countries.unique():
    S = np.array(G.nodes)[graph_countries == 'Russia']
    T = np.array(G.nodes)[graph_countries == i]

    if nx.normalized_cut_size(G, S, T) !=0:
        codependence = pd.concat([codependence, pd.DataFrame(columns = ['country', 'codependence'],
                                                             data = [[i, nx.normalized_cut_size(G, S, T, weight = 'flights')]])])



codependence = codependence.sort_values(by = 'codependence').iloc[25:]
fig = px.bar(codependence, y = 'codependence', x = 'country', orientation='v',
             color = 'codependence',
             height = 500,
             title = 'Созависимость с Россией')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4e5ddd17-6e8d-4ab1-ba73-bc0c4365a1e4" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e5ddd17-6e8d-4ab1-ba73-bc0c4365a1e4")) {                    Plotly.newPlot(                        "4e5ddd17-6e8d-4ab1-ba73-bc0c4365a1e4",                        [{"alignmentgroup":"True","hovertemplate":"country=%{x}<br>codependence=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0.011317714698526504,0.011446741618947135,0.011672455918370425,0.012549857673106705,0.01457461571285468,0.01514486038775717,0.026956749631397242,0.02754237863230878,0.03617571513751013,0.04594100550590521,0.04633836772893176,0.0773675309123854,0.08537625723959835,0.11512166941866939,0.2612017744269878,0.3746708627389996,0.4365619071281774,0.5439748901018708,0.6556940430211095,0.6626764302402229,0.8272982781673807],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Qatar","Bahrain","Kuwait","Cuba","Syria","Israel","Georgia","Serbia","Egypt","United Arab Emirates","Turkmenistan","Kazakhstan","Mongolia","T\u00fcrkiye","Azerbaijan","Uzbekistan","Kyrgyz Republic","Armenia","Tajikistan","Belarus","Russia"],"xaxis":"x","y":[0.011317714698526504,0.011446741618947135,0.011672455918370425,0.012549857673106705,0.01457461571285468,0.01514486038775717,0.026956749631397242,0.02754237863230878,0.03617571513751013,0.04594100550590521,0.04633836772893176,0.0773675309123854,0.08537625723959835,0.11512166941866939,0.2612017744269878,0.3746708627389996,0.4365619071281774,0.5439748901018708,0.6556940430211095,0.6626764302402229,0.8272982781673807],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca ...

# %% [markdown]
# Плюс-минус ожидаемый результат. Сильные связи с постсоветским пространством, с остальными странами связи уже скорее слабые.

# %%
codependence = pd.DataFrame(columns = ['country', 'codependence'])
graph_countries = airports['country']

for i in graph_countries.unique():
    S = np.array(G.nodes)[graph_countries == 'Iran']
    T = np.array(G.nodes)[graph_countries == i]

    if nx.normalized_cut_size(G, S, T) !=0:
        codependence = pd.concat([codependence, pd.DataFrame(columns = ['country', 'codependence'],
                                                             data = [[i, nx.normalized_cut_size(G, S, T, weight = 'flights')]])])



codependence = codependence.sort_values(by = 'codependence')[10:]
fig = px.bar(codependence, y = 'codependence', x = 'country', orientation='v',
             color = 'codependence',
             height = 500,
             title = 'Созависимость с Ираном')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="cd35e538-2d36-4bda-b8fc-bebbae6bd75a" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd35e538-2d36-4bda-b8fc-bebbae6bd75a")) {                    Plotly.newPlot(                        "cd35e538-2d36-4bda-b8fc-bebbae6bd75a",                        [{"alignmentgroup":"True","hovertemplate":"country=%{x}<br>codependence=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0.003932010453428006,0.004493019241053242,0.004813067239786816,0.009141549730030531,0.0193739018326389,0.02131173187291182,0.023640637940898275,0.026255119614126073,0.02805125442226834,0.03058526695379076,0.034790270418491365,0.04867066228393077,0.06247317614499256,0.06613231868885677,0.1456894325505131,0.8013355592654424],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Lebanon","Russia","Germany","Tajikistan","Armenia","Oman","Georgia","Saudi Arabia","Kuwait","Qatar","Syria","Afghanistan","United Arab Emirates","T\u00fcrkiye","Iraq","Iran"],"xaxis":"x","y":[0.003932010453428006,0.004493019241053242,0.004813067239786816,0.009141549730030531,0.0193739018326389,0.02131173187291182,0.023640637940898275,0.026255119614126073,0.02805125442226834,0.03058526695379076,0.034790270418491365,0.04867066228393077,0.06247317614499256,0.06613231868885677,0.1456894325505131,0.8013355592654424],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5 ...

# %% [markdown]
# Тут прям совсем все грустно. Не ожидал, что результат будет сильно хуже Беларуси, но вот... В Иране просто почти все перелеты внутренние, а другие страны туда особо не летают.

# %%
codependence = pd.DataFrame(columns = ['country', 'codependence'])
graph_countries = airports['country']

for i in graph_countries.unique():
    S = np.array(G.nodes)[graph_countries == 'France']
    T = np.array(G.nodes)[graph_countries == i]

    if nx.normalized_cut_size(G, S, T) !=0:
        codependence = pd.concat([codependence, pd.DataFrame(columns = ['country', 'codependence'],
                                                             data = [[i, nx.normalized_cut_size(G, S, T, weight = 'flights')]])])



codependence = codependence.sort_values(by = 'codependence')[95:]
fig = px.bar(codependence, y = 'codependence', x = 'country', orientation='v',
             color = 'codependence',
             height = 700,
             title = 'Созависимость с Францией')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="37b2fcf0-a3e7-48c1-8026-9ced8ebd8aa8" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37b2fcf0-a3e7-48c1-8026-9ced8ebd8aa8")) {                    Plotly.newPlot(                        "37b2fcf0-a3e7-48c1-8026-9ced8ebd8aa8",                        [{"alignmentgroup":"True","hovertemplate":"country=%{x}<br>codependence=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0.08039418573079761,0.08062141347025067,0.08332504643536928,0.08465555067277321,0.08515386422363166,0.09150083440089493,0.09481671406461115,0.09747891518334129,0.10217484926787251,0.10217503663269684,0.10292138978492671,0.11615673298379424,0.11774055713510405,0.12748704711077327,0.1347221526743237,0.1353244705629412,0.15095882125295967,0.1510021556191187,0.16423272828756807,0.189971151463665,0.2371270848015034,0.26686579290870827,0.30731735964294105,0.31227391379656566,0.341432254995363,0.3518097462018569],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Belgium","Niger","Ireland","Netherlands","Slovenia","Luxembourg","Malta","Cote d'Ivoire","Mayotte","Switzerland","Germany","United Kingdom","Guinea","Guadeloupe","Spain","Kosovo","Italy","Benin","Portugal","Martinique","French Guiana","Reunion","France","Morocco","Tunisia","Algeria"],"xaxis":"x","y":[0.08039418573079761,0.08062141347025067,0.08332504643536928,0.08465555067277321,0.08515386422363166,0.09150083440089493,0.09481671406461115,0.09747891518334129,0.10217484926787251,0.10217503663269684,0.10292138978492671,0.11615673298379424,0.11774055713510405,0.12748704711077327,0.1347221526743237,0.1353244705629412,0.15095882125295967,0.1510021556191187,0.16423272828756807,0.189971151463665,0.2371270848015034,0.26686579290870827,0.30731735964294105,0.31227391379656566,0.341432254995363,0.3518097462018569],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111111 ...

# %% [markdown]
# Франция тут выглядит как диверсифицированное государство в плане перелетов. Нет сильной зависимости от внутренних перелетов или от какого-то другого государства.

# %% [markdown]
# ---

# %% [markdown]
# # Итог

# %% [markdown]
# По результатам анализа мировых перелетов мы не можем сделать вывод о том, что Россия осталась отрезана от мировых авиамаршрутов. Все еще сохраняются связи с постсоветским пространством, а также с Турцией. Однако, из резреза графа видно, что внешних связей у России на данный момент все равно мало.
